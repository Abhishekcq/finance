# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishekcq/finance/blob/main/Untitled90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/nifty50_mcwb.csv')
df2=pd.read_csv('/content/niftynext50_mcwb.csv')

# %% [markdown]
# **nifty stocks data with beta, cap and volatility**

# %%
df
# Out:
#               Annexure II-  Nifty 50 Index : Feb 2022       Unnamed: 1  \
# 0                                                 NaN              NaN
# 1                                              Sr. No  Security Symbol
# 2                                                   1       ADANIPORTS
# 3                                                   2       ASIANPAINT
# 4                                                   3         AXISBANK
# ..                                                ...              ...
# 64         * Last day of trading was 28-February-2022              NaN
# 65                                                NaN              NaN
# 66  * Impact Cost for Nifty 50 is for a portfolio ...              NaN
# 67                                                NaN              NaN
# 68  * Impact Cost for Nifty 50 is the weightage av...              NaN
#
#                                     Unnamed: 2           Unnamed: 3  \
# ...

# %% [markdown]
# ****

# %% [markdown]
# **nifty next 50 stocks data with beta, cap and volatility**

# %%
df2
# Out:
#           Annexure II- Nifty Next 50 Index : Jan 2022       Unnamed: 1  \
# 0                                                 NaN              NaN
# 1                                              Sr. No  Security Symbol
# 2                                                   1              ACC
# 3                                                   2         ADANIENT
# 4                                                   3       ADANIGREEN
# ..                                                ...              ...
# 64         * Last day of trading was 28-February-2022              NaN
# 65                                                NaN              NaN
# 66  * Impact Cost for Nifty Next 50 is for a portf...              NaN
# 67                                                NaN              NaN
# 68  * Impact Cost for Nifty Next 50 is the weighta...              NaN
#
#                  Unnamed: 2                  Unnamed: 3  \
# 0                       NaN                         NaN
# ...
