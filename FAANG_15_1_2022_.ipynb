# %%
pip install yfinance
# Out:
# ...
#      |████████████████████████████████| 63 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 6.4 MB 49.0 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ticker=["SPY","FB","AAPL","AMZN","NFLX","GOOG","TSLA"]

# %%
stocks = yf.download(ticker, start = "2010-01-01",end ="2022-01-15")
# Out:
# [*********************100%***********************]  7 of 7 completed

# %%
stocks
# Out:
#              Adj Close                                                    \
#                   AAPL         AMZN          FB         GOOG        NFLX
# Date
# 2010-01-04    6.544689   133.899994         NaN   312.204773    7.640000
# 2010-01-05    6.556005   134.690002         NaN   310.829926    7.358571
# 2010-01-06    6.451722   132.250000         NaN   302.994293    7.617143
# 2010-01-07    6.439795   130.000000         NaN   295.940735    7.485714
# 2010-01-08    6.482608   133.520004         NaN   299.885956    7.614286
# ...                ...          ...         ...          ...         ...
# 2022-01-10  171.970901  3229.719971  328.070007  2771.479980  539.849976
# 2022-01-11  174.857224  3307.239990  334.369995  2800.350098  540.840027
# 2022-01-12  175.306641  3304.139893  333.260010  2832.959961  537.219971
# 2022-01-13  171.970901  3224.280029  326.480011  2782.620117  519.200012
# 2022-01-14  172.849792  3242.760010  331.899994  2795.729980  525.690002
#
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3031 entries, 2010-01-04 to 2022-01-14
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  3031 non-null   float64
#  1   (Adj Close, AMZN)  3031 non-null   float64
#  2   (Adj Close, FB)    2432 non-null   float64
#  3   (Adj Close, GOOG)  3031 non-null   float64
#  4   (Adj Close, NFLX)  3031 non-null   float64
#  5   (Adj Close, SPY)   3031 non-null   float64
#  6   (Adj Close, TSLA)  2909 non-null   float64
#  7   (Close, AAPL)      3031 non-null   float64
#  8   (Close, AMZN)      3031 non-null   float64
#  9   (Close, FB)        2432 non-null   float64
#  10  (Close, GOOG)      3031 non-null   float64
#  11  (Close, NFLX)      3031 non-null   float64
#  12  (Close, SPY)       3031 non-null   float64
#  13  (Close, TSLA)      2909 non-null   float64
#  14  (High, AAPL)       3031 non-null   float64
# ...

# %%
stocks.to_csv("stocks.csv")

# %%
stocks = pd.read_csv("/content/stocks.csv")

# %%
stocks
# Out:
#       Unnamed: 0           Adj Close         Adj Close.1         Adj Close.2  \
# 0            NaN                AAPL                AMZN                  FB
# 1           Date                 NaN                 NaN                 NaN
# 2     2010-01-04   6.544688701629639  133.89999389648438                 NaN
# 3     2010-01-05   6.556005001068115  134.69000244140625                 NaN
# 4     2010-01-06   6.451721668243408              132.25                 NaN
# ...          ...                 ...                 ...                 ...
# 3028  2022-01-10   171.9709014892578   3229.719970703125  328.07000732421875
# 3029  2022-01-11   174.8572235107422   3307.239990234375   334.3699951171875
# 3030  2022-01-12       175.306640625   3304.139892578125    333.260009765625
# 3031  2022-01-13   171.9709014892578   3224.280029296875   326.4800109863281
# 3032  2022-01-14  172.84979248046875   3242.760009765625   331.8999938964844
#
# ...

# %%
stocks = pd.read_csv("stocks.csv",header=[0,1])
stocks = pd.read_csv("stocks.csv",header=[0,1],index_col=[0])
stocks = pd.read_csv("stocks.csv",header=[0,1],index_col=[0], parse_dates=[0])
stocks
# Out:
#              Adj Close                                                    \
#                   AAPL         AMZN          FB         GOOG        NFLX
# Date
# 2010-01-04    6.544689   133.899994         NaN   312.204773    7.640000
# 2010-01-05    6.556005   134.690002         NaN   310.829926    7.358571
# 2010-01-06    6.451722   132.250000         NaN   302.994293    7.617143
# 2010-01-07    6.439795   130.000000         NaN   295.940735    7.485714
# 2010-01-08    6.482608   133.520004         NaN   299.885956    7.614286
# ...                ...          ...         ...          ...         ...
# 2022-01-10  171.970901  3229.719971  328.070007  2771.479980  539.849976
# 2022-01-11  174.857224  3307.239990  334.369995  2800.350098  540.840027
# 2022-01-12  175.306641  3304.139893  333.260010  2832.959961  537.219971
# 2022-01-13  171.970901  3224.280029  326.480011  2782.620117  519.200012
# 2022-01-14  172.849792  3242.760010  331.899994  2795.729980  525.690002
#
# ...

# %%
#convert mult index to one tuple
stocks.columns=stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'), ('Adj Close', 'AMZN'),   ('Adj Close', 'FB'),
#        ('Adj Close', 'GOOG'), ('Adj Close', 'NFLX'),  ('Adj Close', 'SPY'),
#        ('Adj Close', 'TSLA'),     ('Close', 'AAPL'),     ('Close', 'AMZN'),
#              ('Close', 'FB'),     ('Close', 'GOOG'),     ('Close', 'NFLX'),
#             ('Close', 'SPY'),     ('Close', 'TSLA'),      ('High', 'AAPL'),
#             ('High', 'AMZN'),        ('High', 'FB'),      ('High', 'GOOG'),
#             ('High', 'NFLX'),       ('High', 'SPY'),      ('High', 'TSLA'),
#              ('Low', 'AAPL'),       ('Low', 'AMZN'),         ('Low', 'FB'),
#              ('Low', 'GOOG'),       ('Low', 'NFLX'),        ('Low', 'SPY'),
#              ('Low', 'TSLA'),      ('Open', 'AAPL'),      ('Open', 'AMZN'),
#               ('Open', 'FB'),      ('Open', 'GOOG'),      ('Open', 'NFLX'),
#              ('Open', 'SPY'),      ('Open', 'TSLA'),    ('Volume', 'AAPL'),
# ...

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, AMZN)  (Adj Close, FB)  \
# Date
# 2010-01-04           6.544689         133.899994              NaN
# 2010-01-05           6.556005         134.690002              NaN
# 2010-01-06           6.451722         132.250000              NaN
# 2010-01-07           6.439795         130.000000              NaN
# 2010-01-08           6.482608         133.520004              NaN
# ...                       ...                ...              ...
# 2022-01-10         171.970901        3229.719971       328.070007
# 2022-01-11         174.857224        3307.239990       334.369995
# 2022-01-12         175.306641        3304.139893       333.260010
# 2022-01-13         171.970901        3224.280029       326.480011
# 2022-01-14         172.849792        3242.760010       331.899994
#
#             (Adj Close, GOOG)  (Adj Close, NFLX)  (Adj Close, SPY)  \
# Date
# 2010-01-04         312.204773           7.640000         89.889221
# ...

# %%
stocks.columns=pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#              Adj Close                                                    \
#                   AAPL         AMZN          FB         GOOG        NFLX
# Date
# 2010-01-04    6.544689   133.899994         NaN   312.204773    7.640000
# 2010-01-05    6.556005   134.690002         NaN   310.829926    7.358571
# 2010-01-06    6.451722   132.250000         NaN   302.994293    7.617143
# 2010-01-07    6.439795   130.000000         NaN   295.940735    7.485714
# 2010-01-08    6.482608   133.520004         NaN   299.885956    7.614286
# ...                ...          ...         ...          ...         ...
# 2022-01-10  171.970901  3229.719971  328.070007  2771.479980  539.849976
# 2022-01-11  174.857224  3307.239990  334.369995  2800.350098  540.840027
# 2022-01-12  175.306641  3304.139893  333.260010  2832.959961  537.219971
# 2022-01-13  171.970901  3224.280029  326.480011  2782.620117  519.200012
# 2022-01-14  172.849792  3242.760010  331.899994  2795.729980  525.690002
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close', 'AMZN'),
#             ('Adj Close',   'FB'),
#             ('Adj Close', 'GOOG'),
#             ('Adj Close', 'NFLX'),
#             ('Adj Close',  'SPY'),
#             ('Adj Close', 'TSLA'),
#             (    'Close', 'AAPL'),
#             (    'Close', 'AMZN'),
#             (    'Close',   'FB'),
#             (    'Close', 'GOOG'),
#             (    'Close', 'NFLX'),
#             (    'Close',  'SPY'),
#             (    'Close', 'TSLA'),
#             (     'High', 'AAPL'),
#             (     'High', 'AMZN'),
#             (     'High',   'FB'),
#             (     'High', 'GOOG'),
#             (     'High', 'NFLX'),
#             (     'High',  'SPY'),
#             (     'High', 'TSLA'),
#             (      'Low', 'AAPL'),
#             (      'Low', 'AMZN'),
#             (      'Low',   'FB'),
#             (      'Low', 'GOOG'),
#             (      'Low', 'NFLX'),
#             (      'Low',  'SPY'),
# ...

# %%
stocks.describe()
# Out:
#          Adj Close                                                      \
#               AAPL         AMZN           FB         GOOG         NFLX
# count  3031.000000  3031.000000  2432.000000  3031.000000  3031.000000
# mean     41.378644  1073.941867   145.424687   876.144207   181.503297
# std      39.243903  1047.954914    89.523329   641.562796   182.810416
# min       5.873126   108.610001    17.730000   217.220810     7.018571
# 25%      16.214063   258.024994    75.599998   373.627045    32.349287
# 50%      26.102484   595.929993   136.250000   708.400024    97.830002
# 75%      47.081217  1754.755005   189.040005  1143.525024   326.780014
# max     181.778397  3731.409912   382.179993  3014.179932   691.690002
#
#                                        Close                            ...  \
#                SPY         TSLA         AAPL         AMZN           FB  ...
# count  3031.000000  2909.000000  3031.000000  3031.000000  2432.000000  ...
# ...

# %%
close=stocks.loc[:,"Close"].copy()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn")

close.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
#normalisation_close_column
close.iloc[0,0]
# Out:
# 7.643214225769043

# %%
close.FB
# Out:
# Date
# 2010-01-04           NaN
# 2010-01-05           NaN
# 2010-01-06           NaN
# 2010-01-07           NaN
# 2010-01-08           NaN
#                  ...
# 2022-01-10    328.070007
# 2022-01-11    334.369995
# 2022-01-12    333.260010
# 2022-01-13    326.480011
# 2022-01-14    331.899994
# Name: FB, Length: 3031, dtype: float64

# %%
close.FB.div(close.iloc[0,0])
# Out:
# Date
# 2010-01-04          NaN
# 2010-01-05          NaN
# 2010-01-06          NaN
# 2010-01-07          NaN
# 2010-01-08          NaN
#                 ...
# 2022-01-10    42.923042
# 2022-01-11    43.747301
# 2022-01-12    43.602076
# 2022-01-13    42.715015
# 2022-01-14    43.424139
# Name: FB, Length: 3031, dtype: float64

# %%
close.FB.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04            NaN
# 2010-01-05            NaN
# 2010-01-06            NaN
# 2010-01-07            NaN
# 2010-01-08            NaN
#                  ...
# 2022-01-10    4292.304227
# 2022-01-11    4374.730123
# 2022-01-12    4360.207629
# 2022-01-13    4271.501509
# 2022-01-14    4342.413860
# Name: FB, Length: 3031, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL      7.643214
# AMZN    133.899994
# FB             NaN
# GOOG    312.204773
# NFLX      7.640000
# SPY     113.330002
# TSLA           NaN
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
# Out:
#                    AAPL         AMZN  FB        GOOG         NFLX         SPY  \
# Date
# 2010-01-04   100.000000   100.000000 NaN  100.000000   100.000000  100.000000
# 2010-01-05   100.172893   100.589999 NaN   99.559633    96.316377  100.264710
# 2010-01-06    98.579511    98.767742 NaN   97.049859    99.700828  100.335302
# 2010-01-07    98.397266    97.087383 NaN   94.790586    97.980551  100.758846
# 2010-01-08    99.051443    99.716214 NaN   96.054251    99.663430  101.094148
# ...                 ...          ...  ..         ...          ...         ...
# 2022-01-10  2252.848047  2412.038923 NaN  887.712239  7066.099280  410.756201
# 2022-01-11  2290.659357  2469.932891 NaN  896.959413  7079.058067  414.497479
# 2022-01-12  2296.546892  2467.617657 NaN  907.404437  7031.675132  415.618090
# 2022-01-13  2252.848047  2407.976233 NaN  891.280454  6795.811797  409.891460
# 2022-01-14  2264.361592  2421.777564 NaN  895.479577  6880.759315  410.059114
#
#             TSLA
# Date
# ...

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
##APPLE_

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2022-01-10  172.190002
# 2022-01-11  175.080002
# 2022-01-12  175.529999
# 2022-01-13  172.190002
# 2022-01-14  173.070007
#
# [3031 rows x 1 columns]

# %%
ret = aapl.pct_change().dropna()

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3030 entries, 2010-01-05 to 2022-01-14
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3030 non-null   float64
# dtypes: float64(1)
# memory usage: 47.3 KB

# %%
ret.plot(kind="hist",figsize=(12,8), bins=100)
plt.show()

# %%
##mean_varience_std

# %%
daily_mean_ret=ret.mean()
daily_mean_ret
# Out:
# AAPL    0.001187
# dtype: float64

# %%
var_daily=ret.var()
var_daily
# Out:
# AAPL    0.000312
# dtype: float64

# %%
std_daily=np.sqrt(var_daily)
std_daily
# Out:
# AAPL    0.017674
# dtype: float64

# %%
ret.std()
# Out:
# AAPL    0.017674
# dtype: float64

# %%
annual_mean_ret=daily_mean_ret*252
annual_mean_ret
# Out:
# AAPL    0.299005
# dtype: float64

# %%
annual_var_return=var_daily*252
annual_var_return
# Out:
# AAPL    0.07872
# dtype: float64

# %%
annual_std_retuens=np.sqrt(annual_var_return)
annual_std_retuens
# Out:
# AAPL    0.280571
# dtype: float64

# %%
ret.std()*np.sqrt(252)
# Out:
# AAPL    0.280571
# dtype: float64

# %%
ticker=["SPY","AAPL","AMZN","NFLX","GOOG","KO","IBM","DIS","MSFT"]

# %%
stocks = yf.download(ticker, start = "2010-01-01",end ="2021-01-01")
# Out:
# [*********************100%***********************]  9 of 9 completed

# %%
close=stocks.loc[:,"Close"].copy()
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret=close.pct_change().dropna()
ret.head()
# Out:
#                 AAPL      AMZN       DIS      GOOG       IBM        KO  \
# Date
# 2010-01-05  0.001729  0.005900 -0.002495 -0.004404 -0.012080 -0.012097
# 2010-01-06 -0.015906 -0.018116 -0.005314 -0.025209 -0.006496 -0.000355
# 2010-01-07 -0.001849 -0.017013  0.000314 -0.023280 -0.003462 -0.002485
# 2010-01-08  0.006648  0.027077  0.001571  0.013331  0.010035 -0.018509
# 2010-01-11 -0.008821 -0.024041 -0.016311 -0.001512 -0.010470  0.020308
#
#                 MSFT      NFLX       SPY
# Date
# 2010-01-05  0.000323 -0.036836  0.002647
# 2010-01-06 -0.006137  0.035139  0.000704
# 2010-01-07 -0.010400 -0.017254  0.004221
# 2010-01-08  0.006897  0.017176  0.003328
# 2010-01-11 -0.012720 -0.001313  0.001397

# %%
ret.describe().T
# Out:
#        count      mean       std       min       25%       50%       75%  \
# AAPL  2768.0  0.001191  0.017843 -0.128647 -0.007123  0.000903  0.010379
# AMZN  2768.0  0.001353  0.019994 -0.126568 -0.008313  0.001064  0.011647
# DIS   2768.0  0.000749  0.015717 -0.129846 -0.006210  0.000629  0.007901
# GOOG  2768.0  0.000757  0.016390 -0.111008 -0.006525  0.000630  0.008765
# IBM   2768.0  0.000082  0.014132 -0.128507 -0.006321  0.000287  0.006743
# KO    2768.0  0.000298  0.011088 -0.096725 -0.004698  0.000438  0.005706
# MSFT  2768.0  0.000841  0.016012 -0.147390 -0.006939  0.000654  0.008636
# NFLX  2768.0  0.002063  0.032482 -0.348957 -0.012568  0.000419  0.016449
# SPY   2768.0  0.000491  0.010909 -0.109424 -0.003532  0.000637  0.005421
#
#            max
# AAPL  0.119808
# AMZN  0.157457
# DIS   0.144123
# GOOG  0.160524
# IBM   0.113010
# KO    0.064796
# MSFT  0.142169
# NFLX  0.422235
# SPY   0.090603

# %%
summary=ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#           mean       std
# AAPL  0.001191  0.017843
# AMZN  0.001353  0.019994
# DIS   0.000749  0.015717
# GOOG  0.000757  0.016390
# IBM   0.000082  0.014132
# KO    0.000298  0.011088
# MSFT  0.000841  0.016012
# NFLX  0.002063  0.032482
# SPY   0.000491  0.010909

# %%
summary["mean"]=summary["mean"]*252
summary["std"]=summary["std"]*np.sqrt(252)
summary
# Out:
#           mean       std
# AAPL  0.300134  0.283242
# AMZN  0.340843  0.317389
# DIS   0.188696  0.249504
# GOOG  0.190724  0.260183
# IBM   0.020648  0.224345
# KO    0.075091  0.176009
# MSFT  0.211915  0.254185
# NFLX  0.519934  0.515639
# SPY   0.123754  0.173170

# %%
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size=15)
plt.xlabel("Annual risk(std)",fontsize = 15)
plt.ylabel("Annual return",fontsize = 15)
plt.title("Risk/return",fontsize=25)
plt.show()

# %%
##Correlation and Covariance

# %%
ret
# Out:
#                 AAPL      AMZN       DIS      GOOG       IBM        KO  \
# Date
# 2010-01-05  0.001729  0.005900 -0.002495 -0.004404 -0.012080 -0.012097
# 2010-01-06 -0.015906 -0.018116 -0.005314 -0.025209 -0.006496 -0.000355
# 2010-01-07 -0.001849 -0.017013  0.000314 -0.023280 -0.003462 -0.002485
# 2010-01-08  0.006648  0.027077  0.001571  0.013331  0.010035 -0.018509
# 2010-01-11 -0.008821 -0.024041 -0.016311 -0.001512 -0.010470  0.020308
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-24  0.007712 -0.003949  0.001037  0.003735  0.006376  0.006782
# 2020-12-28  0.035766  0.035071  0.029529  0.021416  0.001043  0.013473
# 2020-12-29 -0.013315  0.011584 -0.008722 -0.009780 -0.008172 -0.000554
# 2020-12-30 -0.008527 -0.010882  0.021827 -0.010917  0.004362  0.005727
# 2020-12-31 -0.007703 -0.008801  0.000055  0.007105  0.012385  0.007348
#
#                 MSFT      NFLX       SPY
# Date
# 2010-01-05  0.000323 -0.036836  0.002647
# ...

# %%
ret.cov()
# Out:
#           AAPL      AMZN       DIS      GOOG       IBM        KO      MSFT  \
# AAPL  0.000318  0.000160  0.000115  0.000154  0.000110  0.000067  0.000158
# AMZN  0.000160  0.000400  0.000114  0.000189  0.000101  0.000057  0.000169
# DIS   0.000115  0.000114  0.000247  0.000119  0.000111  0.000085  0.000121
# GOOG  0.000154  0.000189  0.000119  0.000269  0.000107  0.000069  0.000160
# IBM   0.000110  0.000101  0.000111  0.000107  0.000200  0.000079  0.000121
# KO    0.000067  0.000057  0.000085  0.000069  0.000079  0.000123  0.000076
# MSFT  0.000158  0.000169  0.000121  0.000160  0.000121  0.000076  0.000256
# NFLX  0.000146  0.000268  0.000103  0.000176  0.000090  0.000043  0.000158
# SPY   0.000128  0.000122  0.000121  0.000122  0.000108  0.000077  0.000130
#
#           NFLX       SPY
# AAPL  0.000146  0.000128
# AMZN  0.000268  0.000122
# DIS   0.000103  0.000121
# GOOG  0.000176  0.000122
# IBM   0.000090  0.000108
# KO    0.000043  0.000077
# MSFT  0.000158  0.000130
# ...

# %%
ret.corr()
# Out:
#           AAPL      AMZN       DIS      GOOG       IBM        KO      MSFT  \
# AAPL  1.000000  0.448422  0.408513  0.527026  0.436100  0.339213  0.554051
# AMZN  0.448422  1.000000  0.361327  0.575578  0.356526  0.256800  0.529042
# DIS   0.408513  0.361327  1.000000  0.462413  0.497775  0.486514  0.480457
# GOOG  0.527026  0.575578  0.462413  1.000000  0.463655  0.380866  0.610193
# IBM   0.436100  0.356526  0.497775  0.463655  1.000000  0.502436  0.533130
# KO    0.339213  0.256800  0.486514  0.380866  0.502436  1.000000  0.429749
# MSFT  0.554051  0.529042  0.480457  0.610193  0.533130  0.429749  1.000000
# NFLX  0.251751  0.412252  0.202189  0.330561  0.196844  0.119720  0.303052
# SPY   0.659557  0.557703  0.706726  0.681377  0.703342  0.639324  0.744601
#
#           NFLX       SPY
# AAPL  0.251751  0.659557
# AMZN  0.412252  0.557703
# DIS   0.202189  0.706726
# GOOG  0.330561  0.681377
# IBM   0.196844  0.703342
# KO    0.119720  0.639324
# MSFT  0.303052  0.744601
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Reds",annot=True,annot_kws={"size":15},vmax=0.6)
plt.show()
